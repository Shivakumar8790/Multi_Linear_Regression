# %% [markdown]
# # Multilinear regression assiginment-1
# 50_Startups
#
# Prepare a prediction model for profit of 50_startups data.
# Do transformations for getting better predictions of profit and
# make a table containing R^2 value for each prepared model.
# R&D Spend -- Research and devolop spend in the past few years
# Administration -- spend on administration in the past few years
# Marketing Spend -- spend on Marketing in the past few years
# State -- states from which data is collected
# Profit -- profit of each state in the past few years¶

# %%
#Import the data
import pandas as pd

# %%
df1 = pd.read_csv("D:/Shiva Data Science/ExcelR Assignments/Multi Linear Regression/50_Startups.csv", encoding='latin1')
df1
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
#check for missing values
df1.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
# Standardization X Variable
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df1["State"] = LE.fit_transform(df1["State"])
df1["State"]
# Out:
# 0     2
# 1     0
# 2     1
# 3     2
# 4     1
# 5     2
# 6     0
# 7     1
# 8     2
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    1
# 15    2
# 16    0
# 17    2
# 18    1
# 19    2
# 20    0
# 21    2
# 22    1
# 23    1
# 24    2
# 25    0
# 26    1
# 27    2
# 28    1
# 29    2
# 30    1
# 31    2
# 32    0
# 33    1
# 34    0
# 35    2
# 36    1
# 37    0
# 38    2
# 39    0
# 40    0
# 41    1
# 42    0
# 43    2
# 44    0
# 45    2
# 46    1
# 47    0
# 48    2
# 49    0
# Name: State, dtype: int32

# %%
# Standardization Y variable
from sklearn.preprocessing import MinMaxScaler
MM = MinMaxScaler()
df1["Profit"] =pd.DataFrame(MM.fit_transform(df1[["Profit"]]))
df1["Profit"]
# Out:
# 0     1.000000
# 1     0.997355
# 2     0.993178
# 3     0.947292
# 4     0.853171
# 5     0.801382
# 6     0.796490
# 7     0.794407
# 8     0.774468
# 9     0.760661
# 10    0.740175
# 11    0.729686
# 12    0.714629
# 13    0.673644
# 14    0.664044
# 15    0.648921
# 16    0.632454
# 17    0.623317
# 18    0.617103
# 19    0.608713
# 20    0.584482
# 21    0.544157
# 22    0.538747
# 23    0.529634
# 24    0.528609
# 25    0.522146
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 29    0.486108
# 30    0.480099
# 31    0.466280
# 32    0.465966
# 33    0.462312
# 34    0.461939
# 35    0.460626
# 36    0.428126
# 37    0.423852
# 38    0.374747
# 39    0.373489
# 40    0.357914
# 41    0.355430
# 42    0.319951
# 43    0.310156
# 44    0.284485
# 45    0.282940
# 46    0.196020
# 47    0.156990
# 48    0.118211
# 49    0.000000
# Name: Profit, dtype: float64

# %%
# Correlation matrix
df1.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend     State  \
# R&D Spend         1.000000        0.241955         0.724248  0.104685
# Administration    0.241955        1.000000        -0.032154  0.011847
# Marketing Spend   0.724248       -0.032154         1.000000  0.077670
# State             0.104685        0.011847         0.077670  1.000000
# Profit            0.972900        0.200717         0.747766  0.101796
#
#                    Profit
# R&D Spend        0.972900
# Administration   0.200717
# Marketing Spend  0.747766
# State            0.101796
# Profit           1.000000

# %%
#EDA
# Format the plot background and scatter plots for all the variables
import seaborn as sns
sns.set_style(style="darkgrid")
sns.pairplot(df1)

# %%
## Step-3 Split the variables as X and Y

#X = df1[["R&D Spend"]]                                                 #============== Case-1
#X = df1[["R&D Spend","Marketing Spend"]]                        #============== Case-2      
X = df1[["R&D Spend","Marketing Spend","Administration"]]             #============== Case-3   <<<Good>>>>
#X = df1[["R&D Spend","Marketing Spend","Administration","State"]]             #============== Case-4 
Y = df1["Profit"]

# %%
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Model predicted values
Y_pred = LR.predict(X)
Y_pred
# Out:
# array([1.00146088, 0.98251462, 0.94304242, 0.89545509, 0.88668619,
#        0.83848981, 0.80770554, 0.81844583, 0.77182097, 0.7895199 ,
#        0.68041065, 0.68077498, 0.64453417, 0.63524225, 0.75947134,
#        0.74081226, 0.57570536, 0.65047172, 0.64383686, 0.56849629,
#        0.57415262, 0.57798065, 0.56326917, 0.53674391, 0.55570068,
#        0.49305166, 0.54014497, 0.56158593, 0.48979849, 0.49055847,
#        0.47736664, 0.4674302 , 0.4748267 , 0.46870935, 0.41872786,
#        0.4270189 , 0.34128071, 0.42199547, 0.30980909, 0.38882444,
#        0.33863278, 0.33855733, 0.31500662, 0.25614106, 0.28116812,
#        0.18565813, 0.23361137, 0.17912553, 0.19422179, 0.18883688])

# %%
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y,Y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.002
# Root mean square error  0.05

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y,Y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.951

# %%
## R2 values with cases without model improvement
# Case-1      r2_score 0.947
# Case-2      r2_score 0.950
# Case-3      r2_score 0.951
# Case-4      r2_score 0.951

# %% [markdown]
# # Improving the model by by Data cleaning

# %%
## Built full model
import statsmodels.api as sm

model = sm.OLS(Y, X)  # Capitalize OLS
model = model.fit()

# %%
#Variance Inflation Factor (VIF) is a measure of multicollinearity

from statsmodels.stats.outliers_influence import variance_inflation_factor

X1 = df1[["R&D Spend","Marketing Spend","Administration","State"]]
vif = [variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])]
vif

## R&D Spend and Marketing Spend are having moderate level of multicollinearity issuess
# Out:
# [8.386322337836244, 7.674607839106836, 4.815915745674518, 2.382637006599466]

# %%
# residual analysis by using Q-Q plot

import matplotlib.pyplot as plt

QQ_plot = sm.qqplot(model.resid,line="q") # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

list(np.where(model.resid>10))             # No residuals found
# Out:
# [array([], dtype=int64)]

# %%
# Residual plot for homoscedasticity

model.fittedvalues
model.resid

plt.scatter(model.fittedvalues,model.resid)
plt.title("Residual plot")
plt.xlabel("Fitted values")
plt.ylabel("residual value")
plt.show()

# %%
#Residual Vs Regressors
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,"Administration",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,"R&D Spend",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,"Marketing Spend",fig=fig)
plt.show()

# %%
# Model Deletion Diagnostics
# Detecting Influencers/Outliers
# Cook’s Distance

model_influence = model.get_influence()
(cooks , P_value) = model_influence.cooks_distance
(cooks , P_value)
# Out:
# (array([1.67389164e-02, 1.24245218e-02, 5.11837947e-02, 1.72024182e-02,
#         3.64191931e-04, 8.61000908e-04, 2.04023892e-06, 1.20943423e-02,
#         3.69281874e-03, 1.70404503e-04, 2.02715662e-02, 2.62240298e-02,
#         9.07580618e-03, 1.12953302e-03, 6.96428657e-02, 2.22916843e-02,
#         6.30100844e-03, 9.06238877e-03, 1.07804092e-03, 5.86951641e-02,
#         3.64546212e-04, 3.21251950e-02, 5.72706637e-03, 4.80988228e-08,
#         1.69567412e-03, 1.70056381e-03, 4.40438724e-03, 5.43330057e-02,
#         2.01821159e-02, 2.26901011e-03, 4.94448870e-03, 1.27121561e-03,
#         2.65301804e-03, 7.46306418e-04, 5.22947285e-04, 1.40281210e-02,
#         3.15113230e-02, 1.91102404e-02, 7.31739667e-02, 2.89158041e-03,
#         2.32922503e-03, 1.17392286e-02, 5.57225944e-03, 2.80244020e-02,
#         1.76483905e-03, 1.05712956e-01, 1.30924634e-01, 1.69419350e-03,
#         2.79444441e-03, 1.60627147e-01]),
#  array([0.99700789, 0.9980787 , 0.98451633, 0.99688413, 0.99999025,
#         0.99996456, 1.        , 0.9981542 , 0.99968607, 0.99999688,
#         0.99602575, 0.99418551, 0.99879665, 0.99994676, 0.97584984,
#         0.99542593, 0.99930204, 0.9987993 , 0.99995036, 0.98112033,
#         0.99999023, 0.99216041, 0.99939486, 1.        , 0.99990213,
#         0.99990171, 0.99959137, 0.98311593, 0.99605169, 0.99984859,
#         0.9995142 , 0.99993645, 0.99980864, 0.9999714 , 0.99998322,
#         0.99769851, 0.99237959, 0.9963583 , 0.97407638, 0.99978231,
#         0.99984254, 0.99823429, 0.99941915, 0.99358757, 0.99989609,
#         0.95633859, 0.9412192 , 0.99990226, 0.99979317, 0.92228781]))

# %%
# Plot the influence values using the stemplot

fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df1)),np.round(cooks,3))
plt.xlabel("Row index")
plt.ylabel("Cooks dis")
plt.show()

# %%
#index and value of influencer where c is more than 0.5
(np.argmax(cooks),np.max(cooks))
# Out:
# (49, 0.16062714739398867)

# %%
# High Influence points

from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()     # from the plot 38,46 and 49(from cooks distance) are the highly influencers

# %% [markdown]
# # Improving the Model

# %%
# Removing influencer points
df1[df1.index.isin([38,46,49])]
# Out:
#     R&D Spend  Administration  Marketing Spend  State    Profit
# 38   20229.59        65947.93        185265.10      2  0.374747
# 46    1315.46       115816.21        297114.46      1  0.196020
# 49       0.00       116983.80         45173.06      0  0.000000

# %%
df1_new = df1

# %%
df1_new = df1_new.drop(["Marketing Spend"],axis=1) 
df1_new                   # R&D Spend and Marketing Spend are having moderate level of multicollinearity issues
# Out:
#     R&D Spend  Administration  State    Profit
# 0   165349.20       136897.80      2  1.000000
# 1   162597.70       151377.59      0  0.997355
# 2   153441.51       101145.55      1  0.993178
# 3   144372.41       118671.85      2  0.947292
# 4   142107.34        91391.77      1  0.853171
# 5   131876.90        99814.71      2  0.801382
# 6   134615.46       147198.87      0  0.796490
# 7   130298.13       145530.06      1  0.794407
# 8   120542.52       148718.95      2  0.774468
# 9   123334.88       108679.17      0  0.760661
# 10  101913.08       110594.11      1  0.740175
# 11  100671.96        91790.61      0  0.729686
# 12   93863.75       127320.38      1  0.714629
# 13   91992.39       135495.07      0  0.673644
# 14  119943.24       156547.42      1  0.664044
# 15  114523.61       122616.84      2  0.648921
# 16   78013.11       121597.55      0  0.632454
# 17   94657.16       145077.58      2  0.623317
# 18   91749.16       114175.79      1  0.617103
# 19   86419.70       153514.11      2  0.608713
# 20   76253.86       113867.30      0  0.584482
# 21   78389.47       153773.43      2  0.544157
# 22   73994.56       122782.75      1  0.538747
# 23   67532.53       105751.03      1  0.529634
# 24   77044.01        99281.34      2  0.528609
# 25   64664.71       139553.16      0  0.522146
# 26   75328.87       144135.98      1  0.512737
# 27   72107.60       127864.55      2  0.508654
# 28   66051.52       182645.56      1  0.498934
# 29   65605.48       153032.06      2  0.486108
# 30   61994.48       115641.28      1  0.480099
# 31   61136.38       152701.92      2  0.466280
# 32   63408.86       129219.61      0  0.465966
# 33   55493.95       103057.49      1  0.462312
# 34   46426.07       157693.92      0  0.461939
# 35   46014.02        85047.44      2  0.460626
# 36   28663.76       127056.21      1  0.428126
# 37   44069.95        51283.14      0  0.423852
# 38   20229.59        65947.93      2  0.374747
# 39   38558.51        82982.09      0  0.373489
# 40   28754.33       118546.05      0  0.357914
# 41   27892.92        84710.77      1  0.355430
# 42   23640.93        96189.63      0  0.319951
# 43   15505.73       127382.30      2  0.310156
# 44   22177.74       154806.14      0  0.284485
# 45    1000.23       124153.04      2  0.282940
# 46    1315.46       115816.21      1  0.196020
# 47       0.00       135426.92      0  0.156990
# 48     542.05        51743.15      2  0.118211
# 49       0.00       116983.80      0  0.000000

# %%
df1_new = df1_new.drop(df1_new.index[[38,46,49]],axis=0).reset_index()
df1_new                   # High influence points
# Out:
#     index  R&D Spend  Administration  State    Profit
# 0       0  165349.20       136897.80      2  1.000000
# 1       1  162597.70       151377.59      0  0.997355
# 2       2  153441.51       101145.55      1  0.993178
# 3       3  144372.41       118671.85      2  0.947292
# 4       4  142107.34        91391.77      1  0.853171
# 5       5  131876.90        99814.71      2  0.801382
# 6       6  134615.46       147198.87      0  0.796490
# 7       7  130298.13       145530.06      1  0.794407
# 8       8  120542.52       148718.95      2  0.774468
# 9       9  123334.88       108679.17      0  0.760661
# 10     10  101913.08       110594.11      1  0.740175
# 11     11  100671.96        91790.61      0  0.729686
# 12     12   93863.75       127320.38      1  0.714629
# 13     13   91992.39       135495.07      0  0.673644
# 14     14  119943.24       156547.42      1  0.664044
# 15     15  114523.61       122616.84      2  0.648921
# 16     16   78013.11       121597.55      0  0.632454
# 17     17   94657.16       145077.58      2  0.623317
# 18     18   91749.16       114175.79      1  0.617103
# 19     19   86419.70       153514.11      2  0.608713
# 20     20   76253.86       113867.30      0  0.584482
# 21     21   78389.47       153773.43      2  0.544157
# 22     22   73994.56       122782.75      1  0.538747
# 23     23   67532.53       105751.03      1  0.529634
# 24     24   77044.01        99281.34      2  0.528609
# 25     25   64664.71       139553.16      0  0.522146
# 26     26   75328.87       144135.98      1  0.512737
# 27     27   72107.60       127864.55      2  0.508654
# 28     28   66051.52       182645.56      1  0.498934
# 29     29   65605.48       153032.06      2  0.486108
# 30     30   61994.48       115641.28      1  0.480099
# 31     31   61136.38       152701.92      2  0.466280
# 32     32   63408.86       129219.61      0  0.465966
# 33     33   55493.95       103057.49      1  0.462312
# 34     34   46426.07       157693.92      0  0.461939
# 35     35   46014.02        85047.44      2  0.460626
# 36     36   28663.76       127056.21      1  0.428126
# 37     37   44069.95        51283.14      0  0.423852
# 38     39   38558.51        82982.09      0  0.373489
# 39     40   28754.33       118546.05      0  0.357914
# 40     41   27892.92        84710.77      1  0.355430
# 41     42   23640.93        96189.63      0  0.319951
# 42     43   15505.73       127382.30      2  0.310156
# 43     44   22177.74       154806.14      0  0.284485
# 44     45    1000.23       124153.04      2  0.282940
# 45     47       0.00       135426.92      0  0.156990
# 46     48     542.05        51743.15      2  0.118211

# %%
df1_new =df1_new.drop(["index"],axis=1)    #Drop newly created index column
df1_new
# Out:
#     R&D Spend  Administration  State    Profit
# 0   165349.20       136897.80      2  1.000000
# 1   162597.70       151377.59      0  0.997355
# 2   153441.51       101145.55      1  0.993178
# 3   144372.41       118671.85      2  0.947292
# 4   142107.34        91391.77      1  0.853171
# 5   131876.90        99814.71      2  0.801382
# 6   134615.46       147198.87      0  0.796490
# 7   130298.13       145530.06      1  0.794407
# 8   120542.52       148718.95      2  0.774468
# 9   123334.88       108679.17      0  0.760661
# 10  101913.08       110594.11      1  0.740175
# 11  100671.96        91790.61      0  0.729686
# 12   93863.75       127320.38      1  0.714629
# 13   91992.39       135495.07      0  0.673644
# 14  119943.24       156547.42      1  0.664044
# 15  114523.61       122616.84      2  0.648921
# 16   78013.11       121597.55      0  0.632454
# 17   94657.16       145077.58      2  0.623317
# 18   91749.16       114175.79      1  0.617103
# 19   86419.70       153514.11      2  0.608713
# 20   76253.86       113867.30      0  0.584482
# 21   78389.47       153773.43      2  0.544157
# 22   73994.56       122782.75      1  0.538747
# 23   67532.53       105751.03      1  0.529634
# 24   77044.01        99281.34      2  0.528609
# 25   64664.71       139553.16      0  0.522146
# 26   75328.87       144135.98      1  0.512737
# 27   72107.60       127864.55      2  0.508654
# 28   66051.52       182645.56      1  0.498934
# 29   65605.48       153032.06      2  0.486108
# 30   61994.48       115641.28      1  0.480099
# 31   61136.38       152701.92      2  0.466280
# 32   63408.86       129219.61      0  0.465966
# 33   55493.95       103057.49      1  0.462312
# 34   46426.07       157693.92      0  0.461939
# 35   46014.02        85047.44      2  0.460626
# 36   28663.76       127056.21      1  0.428126
# 37   44069.95        51283.14      0  0.423852
# 38   38558.51        82982.09      0  0.373489
# 39   28754.33       118546.05      0  0.357914
# 40   27892.92        84710.77      1  0.355430
# 41   23640.93        96189.63      0  0.319951
# 42   15505.73       127382.30      2  0.310156
# 43   22177.74       154806.14      0  0.284485
# 44    1000.23       124153.04      2  0.282940
# 45       0.00       135426.92      0  0.156990
# 46     542.05        51743.15      2  0.118211

# %%
X = df1_new[["R&D Spend","Administration"]]             #============== Case-3   <<<Good>>>>
Y = df1_new["Profit"]

# %%
## Built full model
import statsmodels.api as sm

model2 = sm.OLS(Y, X)  # Capitalize OLS
model2 = model2.fit()

# %%
# Cook’s Distance

model_influence = model2.get_influence()
(cooks2 , P_value) = model_influence.cooks_distance
(cooks2 , P_value) 

# Plot the influence values using the stemplot

fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df1_new)),np.round(cooks2,3))
plt.xlabel("Row index")
plt.ylabel("Cooks dis")
plt.show()

# %%
#index and value of influencer where c is more than 0.5
(np.argmax(cooks2),np.max(cooks2))
# Out:
# (2, 0.1273741437727387)

# %%
df1_new2 = df1_new.drop(df1_new.index[[2]],axis=0).reset_index()
df1_new2                   # High influence points
# Out:
#     index  R&D Spend  Administration  State    Profit
# 0       0  165349.20       136897.80      2  1.000000
# 1       1  162597.70       151377.59      0  0.997355
# 2       3  144372.41       118671.85      2  0.947292
# 3       4  142107.34        91391.77      1  0.853171
# 4       5  131876.90        99814.71      2  0.801382
# 5       6  134615.46       147198.87      0  0.796490
# 6       7  130298.13       145530.06      1  0.794407
# 7       8  120542.52       148718.95      2  0.774468
# 8       9  123334.88       108679.17      0  0.760661
# 9      10  101913.08       110594.11      1  0.740175
# 10     11  100671.96        91790.61      0  0.729686
# 11     12   93863.75       127320.38      1  0.714629
# 12     13   91992.39       135495.07      0  0.673644
# 13     14  119943.24       156547.42      1  0.664044
# 14     15  114523.61       122616.84      2  0.648921
# 15     16   78013.11       121597.55      0  0.632454
# 16     17   94657.16       145077.58      2  0.623317
# 17     18   91749.16       114175.79      1  0.617103
# 18     19   86419.70       153514.11      2  0.608713
# 19     20   76253.86       113867.30      0  0.584482
# 20     21   78389.47       153773.43      2  0.544157
# 21     22   73994.56       122782.75      1  0.538747
# 22     23   67532.53       105751.03      1  0.529634
# 23     24   77044.01        99281.34      2  0.528609
# 24     25   64664.71       139553.16      0  0.522146
# 25     26   75328.87       144135.98      1  0.512737
# 26     27   72107.60       127864.55      2  0.508654
# 27     28   66051.52       182645.56      1  0.498934
# 28     29   65605.48       153032.06      2  0.486108
# 29     30   61994.48       115641.28      1  0.480099
# 30     31   61136.38       152701.92      2  0.466280
# 31     32   63408.86       129219.61      0  0.465966
# 32     33   55493.95       103057.49      1  0.462312
# 33     34   46426.07       157693.92      0  0.461939
# 34     35   46014.02        85047.44      2  0.460626
# 35     36   28663.76       127056.21      1  0.428126
# 36     37   44069.95        51283.14      0  0.423852
# 37     38   38558.51        82982.09      0  0.373489
# 38     39   28754.33       118546.05      0  0.357914
# 39     40   27892.92        84710.77      1  0.355430
# 40     41   23640.93        96189.63      0  0.319951
# 41     42   15505.73       127382.30      2  0.310156
# 42     43   22177.74       154806.14      0  0.284485
# 43     44    1000.23       124153.04      2  0.282940
# 44     45       0.00       135426.92      0  0.156990
# 45     46     542.05        51743.15      2  0.118211

# %%
df1_new2 =df1_new2.drop(["index"],axis=1)    #Drop newly created index column
df1_new2
# Out:
#     R&D Spend  Administration  State    Profit
# 0   165349.20       136897.80      2  1.000000
# 1   162597.70       151377.59      0  0.997355
# 2   144372.41       118671.85      2  0.947292
# 3   142107.34        91391.77      1  0.853171
# 4   131876.90        99814.71      2  0.801382
# 5   134615.46       147198.87      0  0.796490
# 6   130298.13       145530.06      1  0.794407
# 7   120542.52       148718.95      2  0.774468
# 8   123334.88       108679.17      0  0.760661
# 9   101913.08       110594.11      1  0.740175
# 10  100671.96        91790.61      0  0.729686
# 11   93863.75       127320.38      1  0.714629
# 12   91992.39       135495.07      0  0.673644
# 13  119943.24       156547.42      1  0.664044
# 14  114523.61       122616.84      2  0.648921
# 15   78013.11       121597.55      0  0.632454
# 16   94657.16       145077.58      2  0.623317
# 17   91749.16       114175.79      1  0.617103
# 18   86419.70       153514.11      2  0.608713
# 19   76253.86       113867.30      0  0.584482
# 20   78389.47       153773.43      2  0.544157
# 21   73994.56       122782.75      1  0.538747
# 22   67532.53       105751.03      1  0.529634
# 23   77044.01        99281.34      2  0.528609
# 24   64664.71       139553.16      0  0.522146
# 25   75328.87       144135.98      1  0.512737
# 26   72107.60       127864.55      2  0.508654
# 27   66051.52       182645.56      1  0.498934
# 28   65605.48       153032.06      2  0.486108
# 29   61994.48       115641.28      1  0.480099
# 30   61136.38       152701.92      2  0.466280
# 31   63408.86       129219.61      0  0.465966
# 32   55493.95       103057.49      1  0.462312
# 33   46426.07       157693.92      0  0.461939
# 34   46014.02        85047.44      2  0.460626
# 35   28663.76       127056.21      1  0.428126
# 36   44069.95        51283.14      0  0.423852
# 37   38558.51        82982.09      0  0.373489
# 38   28754.33       118546.05      0  0.357914
# 39   27892.92        84710.77      1  0.355430
# 40   23640.93        96189.63      0  0.319951
# 41   15505.73       127382.30      2  0.310156
# 42   22177.74       154806.14      0  0.284485
# 43    1000.23       124153.04      2  0.282940
# 44       0.00       135426.92      0  0.156990
# 45     542.05        51743.15      2  0.118211

# %% [markdown]
# # Predict new improved model

# %%
## Step-3 Split the variables as X and Y
x = df1_new2[["R&D Spend","Administration"]]             #============== Case-3   <<<Good>>>>
y = df1_new2["Profit"]

# %%
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x,y)
# Out:
# LinearRegression()

# %%
# Model predicted values
y_pred = LR.predict(x)
y_pred
# Out:
# array([0.97386517, 0.95952679, 0.87836807, 0.87077522, 0.82234146,
#        0.82997459, 0.81009621, 0.76443066, 0.78170441, 0.68197642,
#        0.67823016, 0.64278385, 0.63321172, 0.7608056 , 0.73927152,
#        0.56975901, 0.64456251, 0.63437173, 0.60538637, 0.56241616,
#        0.56805133, 0.55096215, 0.52277005, 0.56765382, 0.50581575,
#        0.55486748, 0.54164977, 0.50762986, 0.50873857, 0.49597878,
#        0.4880113 , 0.50109125, 0.46713004, 0.41913332, 0.42502234,
#        0.33990339, 0.4196173 , 0.39060707, 0.34123829, 0.34087074,
#        0.31988367, 0.27873824, 0.3067896 , 0.21169486, 0.20583696,
#        0.21734416])

# %%
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.002
# Root mean square error  0.043

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y,y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.955
